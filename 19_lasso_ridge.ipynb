# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.drop('name',axis = 1,inplace = True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df['origin'] = df['origin'].map({'usa':1,'japan':2,'europe':3})

# %%
df['origin'] = df['origin'].astype(int)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# dtype: object

# %%
#seprate x and y
x = df.drop('mpg', axis =1)
y = df['mpg']

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       3
# 395       1
# 396       1
# 397       1
#
# [398 rows x 7 columns]

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1,random_state=1)

# %%
x_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 58           4          97.5        80.0    2126          17.0          72
# 236          4         140.0        89.0    2755          15.8          77
# 286          8         302.0       129.0    3725          13.4          79
# 353          4         105.0        74.0    2190          14.2          81
# 307          6         173.0       115.0    2700          12.9          79
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 255          4         140.0        88.0    2720          15.4          78
# 72           8         304.0       150.0    3892          12.5          72
# 235          4          97.0        75.0    2265          18.2          77
# 37           6         232.0       100.0    3288          15.5          71
#
#      origin
# 58        1
# 236       1
# 286       1
# 353       3
# 307       1
# ..      ...
# 393       1
# 255       1
# 72        1
# 235       2
# 37        1
#
# [358 rows x 7 columns]

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 174          6         171.0        97.0    2984          14.5          75
# 359          4         141.0        80.0    3230          20.4          81
# 250          8         318.0       140.0    3735          13.2          78
# 274          5         131.0       103.0    2830          15.9          78
# 283          6         232.0        90.0    3265          18.2          79
# 232          8         351.0       149.0    4335          14.5          77
# 117          4          68.0        49.0    1867          19.5          73
# 348          4          89.0        62.0    2050          17.3          81
# 189          8         304.0       120.0    3962          13.9          76
# 106          8         350.0       180.0    4499          12.5          73
# 371          4         135.0        84.0    2525          16.0          82
# 222          8         260.0       110.0    4060          19.0          77
# 261          6         258.0       120.0    3410          15.1          78
# 242          4         121.0       110.0    2600          12.8          77
# 343          4          79.0        58.0    1755          16.9          81
# 179          4         121.0        98.0    2945          14.5          75
# 5            8         429.0       198.0    4341          10.0          70
# 125          6         198.0        95.0    3102          16.5          74
# 90           8         429.0       198.0    4952          11.5          73
# 303          4          85.0        65.0    2020          19.2          79
# 173          4         119.0        97.0    2545          17.0          75
# 233          4          97.0        78.0    1940          14.5          77
# 17           6         200.0        85.0    2587          16.0          70
# 29           4          97.0        88.0    2130          14.5          71
# 315          4         151.0        90.0    3003          20.1          80
# 102          4          97.0        46.0    1950          21.0          73
# 356          4         108.0        75.0    2350          16.8          81
# 246          4          78.0        52.0    1985          19.4          78
# 4            8         302.0       140.0    3449          10.5          70
# 388          4         156.0        92.0    2585          14.5          82
# 386          6         181.0       110.0    2945          16.4          82
# 6            8         454.0       220.0    4354           9.0          70
# 78           4         120.0        87.0    2979          19.5          72
# 267          4         134.0        95.0    2560          14.2          78
# 234          4         151.0        88.0    2740          16.0          77
# 85           8         350.0       175.0    4100          13.0          73
# 185          4          98.0        79.0    2255          17.7          76
# 95           8         455.0       225.0    4951          11.0          73
# 395          4         135.0        84.0    2295          11.6          82
# 132          4         140.0        75.0    2542          17.0          74
#
#      origin
# 174       1
# 359       3
# 250       1
# 274       3
# 283       1
# 232       1
# 117       3
# 348       2
# 189       1
# 106       1
# 371       1
# 222       1
# 261       1
# 242       3
# 343       2
# 179       3
# 5         1
# 125       1
# 90        1
# 303       2
# 173       2
# 233       3
# 17        1
# 29        2
# 315       1
# 102       3
# 356       2
# 246       2
# 4         1
# 388       1
# 386       1
# 6         1
# 78        3
# 267       2
# 234       1
# 85        1
# 185       1
# 95        1
# 395       1
# 132       1

# %%
#simple linear regression model
from sklearn.linear_model import LinearRegression
regression_model = LinearRegression()

# %%
regression_model
# Out:
# LinearRegression()

# %%
regression_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
for i,col_name in enumerate(x_train.columns):
    print(f'the coff for {col_name} is {regression_model.coef_[i]}')
# Out:
# the coff for cylinders is -0.21881353591679775
# the coff for displacement is 0.016497750638731594
# the coff for horsepower is -0.010421608787933488
# the coff for weight is -0.006972611867346296
# the coff for acceleration is 0.08339776422315945
# the coff for model_year is 0.8102096136039452
# the coff for origin is 1.4825725111992214

# %%
#coefficients are relatively smaller, if one independent variable changes 
#slightly there will be not much difference in prediction.
#This is sometime is called smoother model

# %%
from sklearn.metrics import r2_score

y_pred_linear = regression_model.predict(x_test)
r2_linear = r2_score(y_test, y_pred_linear)
print(f"R square of linear regression {r2_linear}")
# Out:
# R square of linear regression 0.8408923657261718

# %%
#ridge regression
from sklearn.linear_model import Ridge
ridge_regression_model = Ridge(alpha = 0.1)
ridge_regression_model.fit(x_train,y_train)

for i,col_name in enumerate(x_train.columns):
    print(f'the coff for {col_name} is {ridge_regression_model.coef_[i]}')
# Out:
# the coff for cylinders is -0.2184670701548393
# the coff for displacement is 0.0164823554251494
# the coff for horsepower is -0.010415107371380893
# the coff for weight is -0.006972395656941723
# the coff for acceleration is 0.08338526958523226
# the coff for model_year is 0.8101558447711678
# the coff for origin is 1.4813694799518022

# %%
# For Ridge Regression evaluation
y_pred_reg = ridge_regression_model.predict(x_test)
r2_ridge  = r2_score(y_test,y_pred_reg)
print(f"R-squared score for Ridge Regression: {r2_ridge}")
# Out:
# R-squared score for Ridge Regression: 0.8409006238582765

# %%
#lasso regression
from sklearn.linear_model import Lasso
lasso_redge_model = Lasso(alpha = 0.5)
lasso_redge_model.fit(x_train,y_train)

for i, col_name in enumerate(x_train.columns):
    print(f"The coefficient for {col_name} is {lasso_redge_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is -6.402703737421241e-05
# The coefficient for horsepower is -0.007961187208156292
# The coefficient for weight is -0.0064942820433890325
# The coefficient for acceleration is 0.0
# The coefficient for model_year is 0.7247919829222947
# The coefficient for origin is 0.02385538241160282

# %%
#3 features coefficients are 0, Lasso helps in feature selection

# %%
y_pred_lasso =lasso_redge_model.predict(x_test)
r2_lasso = r2_score(y_test, y_pred_lasso)
print(f"R-squared score for Lasso Regression: {r2_lasso}")
# Out:
# R-squared score for Lasso Regression: 0.8373406766754098

# %%
# Predict on the test set
y_pred_elastic_net = elastic_net_model.predict(x_test)

# Calculate evaluation metrics
r2_elastic_net = r2_score(y_test, y_pred_elastic_net)


print(f"R-squared score for Elastic Net Regression: {r2_elastic_net}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 2
#       1 # Predict on the test set
# ----> 2 y_pred_elastic_net = elastic_net_model.predict(x_test)
#       4 # Calculate evaluation metrics
#       5 r2_elastic_net = r2_score(y_test, y_pred_elastic_net)
#
# NameError: name 'elastic_net_model' is not defined
