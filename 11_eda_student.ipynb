# %%
#Import all the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('student-por.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#Univariate analysis

df['school'].value_counts()
# Out:
# GP    423
# MS    226
# Name: school, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='school',data=df,palette = 'pastel')
plt.title('Dist of school')
plt.xlabel('school')
plt.ylabel('count')
plt.show()

# %%
#GP has larger no of stiudents

# %%
sns.histplot(df['age'],kde = True,bins = 10,palette = 'viridis')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
#most common age group >> 15-16
#skewed dist

# %%
df['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x = 'address',data = df,palette = 'dark')
# Out:
# <AxesSubplot: xlabel='address', ylabel='count'>

# %%
#There are many students from urban areas

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_counts = df['reason'].value_counts()
plt.pie(reason_counts, labels = reason_counts.index,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f154b9eabc0>,
#   <matplotlib.patches.Wedge at 0x7f154b8240d0>,
#   <matplotlib.patches.Wedge at 0x7f154b824760>,
#   <matplotlib.patches.Wedge at 0x7f154b824df0>],
#  [Text(0.2090477294642692, 1.0799532613987672, 'course'),
#   Text(-1.0374525300139155, -0.3656395054800917, 'home'),
#   Text(0.19858270739717565, -1.0819264800913266, 'reputation'),
#   Text(1.0338640880804848, -0.37566613818323835, 'other')],
#  [Text(0.11402603425323773, 0.5890654153084184, '43.9%'),
#   Text(-0.5658831981894084, -0.19943973026186818, '23.0%'),
#   Text(0.10831784039845943, -0.5901417164134508, '22.0%'),
#   Text(0.5639258662257188, -0.2049088026454027, '11.1%')])

# %%
##common reason>> would be course
act = df['activities'].value_counts()
plt.pie(act,labels = act.index,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f154b853460>,
#   <matplotlib.patches.Wedge at 0x7f154b8539d0>],
#  [Text(-0.050567080655621474, 1.0988370990979364, 'no'),
#   Text(0.05056697777506705, -1.0988371038323632, 'yes')],
#  [Text(-0.027582043993975347, 0.5993656904170561, '51.5%'),
#   Text(0.027581987877309297, -0.5993656929994708, '48.5%')])

# %%
#48.5% are participating

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
walc = df['Walc'].value_counts()
plt.pie(walc,labels = walc.index,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f154b8ba080>,
#   <matplotlib.patches.Wedge at 0x7f154b8ba710>,
#   <matplotlib.patches.Wedge at 0x7f154b8bada0>,
#   <matplotlib.patches.Wedge at 0x7f154b8bb430>,
#   <matplotlib.patches.Wedge at 0x7f154b8bbac0>],
#  [Text(0.4030549984700621, 1.0234972731806853, '1'),
#   Text(-1.0996778255423472, 0.02662104450346281, '2'),
#   Text(-0.31245939664709116, -1.05468911317361, '3'),
#   Text(0.7203468250294088, -0.8313245164615624, '4'),
#   Text(1.0740055804868376, -0.2377225548473076, '5')],
#  [Text(0.2198481809836702, 0.5582712399167374, '38.1%'),
#   Text(-0.5998242684776438, 0.01452056972916153, '23.1%'),
#   Text(-0.17043239817114061, -0.575284970821969, '18.5%'),
#   Text(0.39291645001604114, -0.4534497362517612, '13.4%'),
#   Text(0.5858212257200932, -0.1296668480985314, '6.9%')])

# %%
#insights >> 45 students have regular weekend alcohal consumption

# %%
dalc = df['Dalc'].value_counts()
plt.pie(dalc,labels = dalc.index,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f154b9165c0>,
#   <matplotlib.patches.Wedge at 0x7f154b916c50>,
#   <matplotlib.patches.Wedge at 0x7f154b9172e0>,
#   <matplotlib.patches.Wedge at 0x7f154b917970>,
#   <matplotlib.patches.Wedge at 0x7f154b750040>],
#  [Text(-0.6322660969560419, 0.9001330916258846, '1'),
#   Text(0.261059235896968, -1.068572915318787, '2'),
#   Text(0.9449951383804163, -0.5630134886815573, '3'),
#   Text(1.0666491428498037, -0.2688114693568322, '5'),
#   Text(1.0962775639680993, -0.09041848671687727, '4')],
#  [Text(-0.3448724165214774, 0.4909816863413915, '69.5%'),
#   Text(0.14239594685289161, -0.5828579538102474, '18.6%'),
#   Text(0.5154518936620452, -0.3070982665535767, '6.6%'),
#   Text(0.5818086233726202, -0.14662443783099938, '2.6%'),
#   Text(0.5979695803462359, -0.04931917457284215, '2.6%')])

# %%
#Bivariate analysis
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize = (12,6))

plt.subplot(1,2,1)
sns.countplot(x = 'Medu',data = df,palette = 'Set2')
plt.xlabel('mother ed label')
plt.ylabel('count plot')
plt.title('mother ed dist label')



plt.subplot(1,2,2)
sns.countplot(x = 'Fedu',data = df,palette = 'Set2')
plt.xlabel('mother ed label')
plt.ylabel('count plot')
plt.title('mother ed dist label')
# Out:
# Text(0.5, 1.0, 'mother ed dist label')

# %%
sns.barplot(x='studytime',y = 'G3',data = df)
# Out:
# <AxesSubplot: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot(x = 'studytime', y = 'G3', data=df)
# Out:
# <AxesSubplot: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot(x = 'internet', y = 'G3', data=df)
# Out:
# <AxesSubplot: xlabel='internet', ylabel='G3'>

# %%
num_cols = ['age','traveltime','studytime','absences','G1','G2','G3']
sns.boxplot(data = df[num_cols],palette = 'Set2')
# Out:
# <AxesSubplot: >

# %%
#insights>>median age is 17,

# %%
corr = df.corr(numeric_only = True)

# %%
plt.figure(figsize = (12,10))
sns.heatmap(corr,annot = True,cmap = "coolwarm",fmt='.2f')
plt.show()

# %%
#insights>> strong positive correlation, strong negative correlation

# %%
#outlier detection

# %%
students_grades_df = df.copy()
students_grades_df = students_grades_df.drop(['G1','G2','G3'],axis = 1)

# %%
students_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0    ...    yes       no        no       4         3     4    1    1      3
# 1    ...    yes      yes        no       5         3     3    1    1      3
# 2    ...    yes      yes        no       4         3     2    2    3      3
# 3    ...    yes      yes       yes       3         2     2    1    1      5
# 4    ...    yes       no        no       4         3     2    1    2      5
# ..   ...    ...      ...       ...     ...       ...   ...  ...  ...    ...
# 644  ...    yes      yes        no       5         4     2    1    2      5
# 645  ...    yes      yes        no       4         3     4    1    1      1
# 646  ...    yes       no        no       1         1     1    1    1      5
# 647  ...    yes      yes        no       2         4     5    3    4      2
# 648  ...    yes      yes        no       4         4     1    3    4      5
#
#     absences
# 0          4
# 1          2
# 2          6
# 3          0
# 4          0
# ..       ...
# 644        4
# 645        4
# 646        6
# 647        6
# 648        4
#
# [649 rows x 30 columns]

# %%
def detect_outliers(columns):
    outlier_indices = []
    for column in columns:
        Q1 = students_grades_df[column].quantile(0.25)
        Q3 = students_grades_df[column].quantile(0.75)
        
        IQR = Q3 - Q1
        #mask is boolean condition
        mask = (students_grades_df[column] >= (Q1 - 1.5) * IQR) & (students_grades_df[column] <= (Q1 + 1.5) * IQR) 
        mask = mask.to_numpy()#bool value to numpy array
        #find the indices of values that do not satisfy the mask condition >> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
    return np.unique(np.concatenate(outlier_indices).ravel())

# %%
num_cols = ['age', 'absences']
outlier_indices = detect_outliers(num_cols)

# %%
num_cols
# Out:
# ['age', 'absences']

# %%
#data split

# %%
students_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0    ...    yes       no        no       4         3     4    1    1      3
# 1    ...    yes      yes        no       5         3     3    1    1      3
# 2    ...    yes      yes        no       4         3     2    2    3      3
# 3    ...    yes      yes       yes       3         2     2    1    1      5
# 4    ...    yes       no        no       4         3     2    1    2      5
# ..   ...    ...      ...       ...     ...       ...   ...  ...  ...    ...
# 644  ...    yes      yes        no       5         4     2    1    2      5
# 645  ...    yes      yes        no       4         3     4    1    1      1
# 646  ...    yes       no        no       1         1     1    1    1      5
# 647  ...    yes      yes        no       2         4     5    3    4      2
# 648  ...    yes      yes        no       4         4     1    3    4      5
#
#     absences
# 0          4
# 1          2
# 2          6
# 3          0
# 4          0
# ..       ...
# 644        4
# 645        4
# 646        6
# 647        6
# 648        4
#
# [649 rows x 30 columns]

# %%
students_grades_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences'],
#       dtype='object')

# %%
X, y = students_grades_df.iloc[:, :-1], students_grades_df.iloc[:, -1]

# %%
X
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... nursery higher  internet  romantic  famrel freetime goout Dalc Walc  \
# 0    ...     yes    yes        no        no       4        3     4    1    1
# 1    ...      no    yes       yes        no       5        3     3    1    1
# 2    ...     yes    yes       yes        no       4        3     2    2    3
# 3    ...     yes    yes       yes       yes       3        2     2    1    1
# 4    ...     yes    yes        no        no       4        3     2    1    2
# ..   ...     ...    ...       ...       ...     ...      ...   ...  ...  ...
# 644  ...      no    yes       yes        no       5        4     2    1    2
# 645  ...     yes    yes       yes        no       4        3     4    1    1
# 646  ...     yes    yes        no        no       1        1     1    1    1
# 647  ...      no    yes       yes        no       2        4     5    3    4
# 648  ...      no    yes       yes        no       4        4     1    3    4
#
#     health
# 0        3
# 1        3
# 2        3
# 3        5
# 4        5
# ..     ...
# 644      5
# 645      1
# 646      5
# 647      2
# 648      5
#
# [649 rows x 29 columns]

# %%
y
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (486, 29)

# %%
X_test.shape
# Out:
# (163, 29)

# %%
X_train
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 248     GP   M   16       U     LE3       T     1     1     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 408     GP   M   18       U     LE3       T     2     2  services  services
# 574     MS   M   20       R     GT3       T     1     1     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 144     GP   F   16       R     GT3       T     1     1     other  services
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 72      GP   F   15       R     GT3       T     1     1     other     other
# 235     GP   F   17       U     GT3       T     1     1   at_home     other
# 37      GP   M   16       R     GT3       A     4     4     other   teacher
#
#      ... nursery higher  internet  romantic  famrel freetime goout Dalc Walc  \
# 40   ...      no    yes       yes       yes       3        3     3    1    2
# 248  ...     yes    yes       yes        no       3        4     2    1    1
# 5    ...     yes    yes       yes        no       5        4     2    1    2
# 408  ...      no     no       yes        no       4        4     4    1    3
# 574  ...     yes     no       yes       yes       4        4     3    2    4
# ..   ...     ...    ...       ...       ...     ...      ...   ...  ...  ...
# 144  ...     yes    yes        no       yes       3        3     3    1    2
# 645  ...     yes    yes       yes        no       4        3     4    1    1
# 72   ...      no    yes       yes       yes       3        3     4    2    4
# 235  ...     yes    yes        no       yes       4        3     4    1    1
# 37   ...     yes    yes       yes       yes       2        4     3    1    1
#
#     health
# 40       3
# 248      5
# 5        5
# 408      3
# 574      4
# ..     ...
# 144      1
# 645      1
# 72       5
# 235      5
# 37       5
#
# [486 rows x 29 columns]

# %%
#encoding of data
#internal homeworks>>encoding of data
